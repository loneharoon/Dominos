# %%
# %matplotlib inline
from IPython.html import widgets
from IPython.display import display, clear_output
import plotly.plotly as py
import plotly
import plotly.graph_objs as go
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /Volumes/MacintoshHD2/Users/haroonr/anaconda/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning:
#
# The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.

# %%
dir = "/Volumes/MacintoshHD2/Users/haroonr/Detailed_datasets/Dominos/"
store = "Dominos-22"
power = "power_makeline.csv"
pdf = pd.read_csv(dir + store + '/' + power,index_col="Datetime")
pdf.index = pd.to_datetime(pdf.index)
pdf_samp = pdf.resample('5T',label = 'right', closed ='right').mean()

# %%
pdf_samp['2018-02-01'].plot()

# %%
py.plot(pdf_samp['2018-02-01'])
#plotly.tools.embed(url)
# Out:
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-24-e706e5a1e686> in <module>()
# ----> 1 py.plot(pdf_samp['2018-02-01'])
#       2 #plotly.tools.embed(url)
#
# /Volumes/MacintoshHD2/Users/haroonr/anaconda/lib/python3.5/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     199
#     200     """
# --> 201     figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     202     for entry in figure['data']:
#     203         if ('type' in entry) and (entry['type'] == 'scattergl'):
#
# /Volumes/MacintoshHD2/Users/haroonr/anaconda/lib/python3.5/site-packages/plotly/tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#    1452         figure = {'data': figure_or_data}
#    1453     else:
# -> 1454         raise exceptions.PlotlyError("The `figure_or_data` positional "
#    1455                                      "argument must be either "
#    1456                                      "`dict`-like or `list`-like.")
#
# PlotlyError: The `figure_or_data` positional argument must be either `dict`-like or `list`-like.
